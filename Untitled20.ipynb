# %% [markdown]
# <a href="https://colab.research.google.com/github/amlsouid/Herbal-SkinCare-Advisor/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# مساعد إدارة المخزون من إيكو-بوت

المخزون = { "حليب" : { "المخزون" :  20 ,  "تاريخ الانتهاء" :  "5 أيام" }, "خبز" : { "المخزون" :  5 ,  "تاريخ الانتهاء" :  "يومان" }, "أرز" : { "المخزون" :  50 ,  "تاريخ الانتهاء" :  "180 يومًا" }, "عصير" : { "المخزون" :  8 ,  "تاريخ الانتهاء" :  "10 أيام" } }






اطبع ( "🤖 مرحبًا بك في إيكو-بوت" )
اطبع ( "اسأل عن: المخزون، المخزون الناقص، المنتجات، تاريخ انتهاء الصلاحية" )
اطبع ( "اكتب 'exit' للخروج" )

بينما صحيح :
    السؤال =  إدخال ( "أنت: " ).lower()

    إذا كان  السؤال يساوي  "خروج" : اطبع ( "الروبوت البيئي: وداعًا!" ) ثم توقف.



    elif "products" in  question:   print ( "Eco-Bot: Available products:" ) for  product  in  inventory: print ( "-" , product)




    elif "stock" in  question  and "milk" in  question:     print ( f "Eco-Bot: Milk stock =  {inventory[ 'milk' ][ 'stock' ]} " )


    elif "stock" و "bread" هما  العنصران  المطلوبان  :     print ( f "Eco-Bot: Bread stock =  {inventory[ 'bread' ][ 'stock' ]} " )


    وإذا كان "المخزون المنخفض" هو المقصود  :   اطبع ( "Eco-Bot: المنتجات ذات المخزون المنخفض:" ) لكل  منتج وبيانات  في  عناصر المخزون: إذا كانت  البيانات[ "المخزون" ] أقل من  10 : اطبع ( "-" , المنتج)





    elif "expiry" in question:
        print("Eco-Bot: Product expiry information:")
        for product, data in inventory.items():
            print(product, ":", data["expiry"])

    else:
        print("Eco-Bot: Sorry, I don't understand the question.")
# Out:
# 🤖 Welcome to Eco-Bot
# Ask about: stock, low stock, products, expiry
# Type 'exit' to quit
